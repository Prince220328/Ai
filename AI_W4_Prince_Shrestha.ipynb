# %% [markdown]
# Name: Prince Shrestha
#
# Group: 7

# %%
pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras) (24.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)

# %%
import tensorflow as tf
print(tf.keras.__version__)
# Out:
# 3.8.0

# %%
import tensorflow as tf
x = tf.Variable(5.0) # Trainable variable
with tf.GradientTape() as tape:
  y = x ** 2 # y = x^2
grad = tape.gradient(y, x) # Computes dy/dx automatically
print(grad.numpy()) # Output: 10.0
# Out:
# 10.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %%
# !unzip "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/Copy of Copy of devnagari digit.zip" -d "/content/drive/MyDrive/Artificial Intelligent and Machine Learning"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10299.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10300.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10301.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10302.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10303.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10304.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10306.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/10307.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104017.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104018.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104019.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104021.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104023.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104024.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104025.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104026.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104027.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104028.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104029.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104030.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104031.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104032.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104033.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104034.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104057.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104058.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104059.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104060.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104061.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104062.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104065.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104066.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104067.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104068.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104069.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104070.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104071.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104072.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104075.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104076.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104078.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104079.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104080.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104082.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104084.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104085.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104086.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104087.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104088.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104089.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104090.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104092.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104094.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104095.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104096.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104098.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104099.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/104101.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12706.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12707.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12709.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12711.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12712.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12713.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12714.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12715.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12716.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12718.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12720.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12721.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12723.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12724.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12725.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12726.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12727.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12728.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12730.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12731.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12732.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12733.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12734.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12735.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12736.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12737.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12738.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/12739.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13582.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13583.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13584.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13586.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13587.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13588.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13589.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13590.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13591.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13592.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13593.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13594.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13595.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13596.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13597.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13598.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13600.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/13601.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22874.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22875.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22876.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22877.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22878.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22879.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22880.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22881.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22882.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22883.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22884.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22885.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22886.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22887.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22888.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22889.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/22890.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30200.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30201.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30202.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30203.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30204.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30205.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30206.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30207.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30208.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30209.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30210.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30211.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30212.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30213.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30214.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30215.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30216.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30217.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30218.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30219.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30220.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30221.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30222.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30223.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30224.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30225.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30226.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30227.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30228.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30229.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30231.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30232.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30233.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30234.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30236.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30237.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30238.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30239.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30240.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30241.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30242.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30243.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30244.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30246.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30247.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30248.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30249.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30250.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30251.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30252.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30253.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30254.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30255.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30256.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30257.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30258.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30259.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30260.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30261.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30262.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30263.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30264.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30265.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30266.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30267.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30269.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30270.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30271.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30272.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30273.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30274.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30275.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30276.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30277.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30278.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30279.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30280.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30282.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30283.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30284.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30285.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30286.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30287.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30288.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30289.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30290.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30291.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30292.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30293.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30294.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30295.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30296.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30297.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30298.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30299.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30300.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30301.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30302.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30303.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30304.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30305.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30307.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30308.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30311.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30312.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30313.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30314.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30315.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30316.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30317.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30318.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30319.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30320.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30321.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30322.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30323.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30324.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30325.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30326.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30327.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30330.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30331.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30332.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30333.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30334.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30335.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30337.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30338.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30339.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30340.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30341.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30342.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30343.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30344.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30345.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30346.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30347.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30348.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30349.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30350.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30351.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30352.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30353.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30354.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30355.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30356.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30357.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30358.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30359.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30361.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30362.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30365.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30366.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30367.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30368.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30369.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30370.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30371.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30372.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30373.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30374.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30375.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30376.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30378.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30379.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30380.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30381.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30382.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30383.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30385.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30386.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30387.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30389.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30390.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30391.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30393.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30394.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30395.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30396.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30398.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30399.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30400.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30401.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30402.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30403.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30404.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30405.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30407.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30409.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30410.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30411.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30412.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30413.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30414.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30415.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30416.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30417.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30418.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30419.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30420.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30421.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30422.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30423.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30424.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30425.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30426.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30427.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30428.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30430.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30431.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30433.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30435.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30436.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30437.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30438.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30439.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30440.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30442.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30444.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30445.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_7/30446.png
# ...
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99663.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99664.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99665.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99666.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99667.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99668.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99669.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99670.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99671.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99672.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99673.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99674.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99675.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99676.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99677.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99678.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99680.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99681.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99682.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99685.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99686.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99688.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99689.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99690.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99691.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99692.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99693.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99694.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99695.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99696.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99697.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99698.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99699.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99700.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99701.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99704.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99705.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99706.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99707.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99708.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99729.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99730.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99731.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99732.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99733.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99734.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99735.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99736.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99737.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99738.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99739.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99740.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99741.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99742.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99743.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99744.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99745.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99746.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99747.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99748.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99749.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99750.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99753.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99754.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99755.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99756.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99757.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99758.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99759.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99760.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99761.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99762.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99763.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99764.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99766.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99767.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99768.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99769.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99770.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99771.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99773.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99776.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99778.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99779.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99780.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99781.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99783.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99784.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99785.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99787.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99788.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99789.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99790.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99791.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99793.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99795.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99797.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99799.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99800.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99802.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99803.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99804.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99805.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99806.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99808.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99809.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99811.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99812.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99813.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99814.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99815.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99816.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99817.png
#   inflating: /content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train/digit_9/99818.png

# %%
# !ls "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Test"
# Out:
# digit_0  digit_2  digit_4  digit_6  digit_8
# digit_1  digit_3  digit_5  digit_7  digit_9

# %%
# !ls "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train"
# Out:
# digit_0  digit_2  digit_4  digit_6  digit_8
# digit_1  digit_3  digit_5  digit_7  digit_9

# %%
from PIL import Image
import os
import numpy as np

# Path to the dataset folder
dataset_path = "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train"

# Placeholder for images and labels
images = []
labels = []

# Iterate through each folder and file
for label_folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, label_folder)
    if os.path.isdir(folder_path):  # Ensure it’s a directory
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if file_name.endswith('.png'):  # Assuming images are PNG files
                # Open and process image
                image = Image.open(file_path).convert('L')  # Convert to grayscale
                image_array = np.array(image)  # Convert to numpy array
                images.append(image_array)
                labels.append(label_folder)  # Use folder name as label

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

print(f"Loaded {len(images)} images with labels.")
# Out:
# Loaded 17000 images with labels.

# %%
from PIL import Image
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

# Function to load, process, and normalize images
def load_images_and_labels(folder_path, target_size=(28, 28)):
    images = []
    labels = []
    label_mapping = {}  # To map folder names to numerical labels
    current_label = 0

    # Iterate through folders (each folder represents a class)
    for label_folder in sorted(os.listdir(folder_path)):  # Ensure consistent label order
        label_path = os.path.join(folder_path, label_folder)
        if os.path.isdir(label_path):
            # Map folder name to a numerical label
            if label_folder not in label_mapping:
                label_mapping[label_folder] = current_label
                current_label += 1

            for file_name in os.listdir(label_path):
                file_path = os.path.join(label_path, file_name)
                if file_name.endswith('.png'):  # Check for PNG files
                    # Load image, resize to target size, and convert to grayscale
                    image = Image.open(file_path).convert('L').resize(target_size)
                    image_array = np.array(image, dtype=np.float32)  # Convert to NumPy array
                    image_array /= 255.0  # Normalize to range 0-1
                    images.append(image_array)
                    labels.append(label_mapping[label_folder])  # Assign numerical label

    # Convert to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels, label_mapping

# Paths to the train and test folders
train_folder = "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Train"
test_folder = "/content/drive/MyDrive/Artificial Intelligent and Machine Learning/DevanagariHandwrittenDigitDataset/Test"

# Load and process training and testing data
train_images, train_labels, label_mapping = load_images_and_labels(train_folder)
test_images, test_labels, _ = load_images_and_labels(test_folder)

# ✅ Shuffle after loading!
train_images, train_labels = shuffle(train_images, train_labels, random_state=42)

# One-hot encode the labels for multi-class classification
train_labels = to_categorical(train_labels, num_classes=len(label_mapping))
test_labels = to_categorical(test_labels, num_classes=len(label_mapping))

# Confirm everything looks good
print(f"Training set: {train_images.shape[0]} images, {train_labels.shape[0]} labels.")
print(f"Testing set: {test_images.shape[0]} images, {test_labels.shape[0]} labels.")
print(f"Label Mapping: {label_mapping}")
print(os.listdir(train_folder))
# Out:
# Training set: 17000 images, 17000 labels.
# Testing set: 3000 images, 3000 labels.
# Label Mapping: {'digit_0': 0, 'digit_1': 1, 'digit_2': 2, 'digit_3': 3, 'digit_4': 4, 'digit_5': 5, 'digit_6': 6, 'digit_7': 7, 'digit_8': 8, 'digit_9': 9}
# ['digit_0', 'digit_1', 'digit_2', 'digit_3', 'digit_4', 'digit_5', 'digit_6', 'digit_7', 'digit_8', 'digit_9']

# %% [markdown]
# Task 2: Build the FCN Model
# Model Architecture
# • Create a Sequential model using Keras.
# • Add 3 hidden layers with the following number of neurons:
#
# – 1st hidden layer: 64 neurons
#
# – 2nd hidden layer: 128 neurons
#
# – 3rd hidden layer: 256 neurons
#
# • Use sigmoid activation functions for all hidden layers.
#
# • Add an output layer with 10 units with softmax (since Devnagari digits have 10 classes) and a
# softmax activation function.

# %%
from tensorflow.keras.models import Sequential

# Initialize the Sequential model
model = Sequential()

print("Sequential model initialized.")
# Out:
# Sequential model initialized.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Task 3: Compile the Model
#
# Model Compilation
#
# • Choose an appropriate optimizer (e.g., Adam), loss function (e.g., sparse categorical crossentropy),
# and evaluation metric (e.g., accuracy).

# %%
from tensorflow.keras.optimizers import Adam

# Compile the previously built model
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %%
print(f"Shape of train_images: {train_images.shape}")
print(f"Shape of train_labels: {train_labels.shape}")
# Out:
# Shape of train_images: (17000, 28, 28)
# Shape of train_labels: (17000, 10)

# %% [markdown]
# Task 4: Train the Model
#
# Model Training
#
# • Use the model.fit() function to train the model. Set the batch size to 128 and the number of
# epochs to 20.
#
# • Use validation split (validation split=0.2) to monitor the model’s performance on validation
# data.
#
# • Optionally, use callbacks such as ModelCheckpoint and EarlyStopping for saving the best model and avoiding overfitting.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Set up callbacks
checkpoint = ModelCheckpoint("best_model.h5", monitor="val_loss", save_best_only=True)
early_stopping = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
callbacks = [checkpoint, early_stopping]

# Train the model
history = model.fit(
    train_images, train_labels,
    batch_size=128,
    epochs=20,
    validation_split=0.2,
    callbacks=[checkpoint, early_stopping]
)

# Print summary
print(model.summary())
# Out:
# Epoch 1/20
# 106/107 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6752 - loss: 1.0989
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.6782 - loss: 1.0891 - val_accuracy: 0.9121 - val_loss: 0.2405
# Epoch 2/20
# 104/107 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9453 - loss: 0.1733
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9455 - loss: 0.1727 - val_accuracy: 0.9629 - val_loss: 0.1254
# Epoch 3/20
#  97/107 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9687 - loss: 0.1076
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.1070 - val_accuracy: 0.9721 - val_loss: 0.0931
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9825 - loss: 0.0624 - val_accuracy: 0.9685 - val_loss: 0.0946
# Epoch 5/20
#  98/107 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9822 - loss: 0.0613
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9822 - loss: 0.0609 - val_accuracy: 0.9747 - val_loss: 0.0832
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9888 - loss: 0.0398 - val_accuracy: 0.9715 - val_loss: 0.0970
# Epoch 7/20
# 103/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.0315
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9909 - loss: 0.0316 - val_accuracy: 0.9835 - val_loss: 0.0581
# Epoch 8/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9943 - loss: 0.0198 - val_accuracy: 0.9800 - val_loss: 0.0614
# Epoch 9/20
# 104/107 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.0194
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9951 - loss: 0.0194 - val_accuracy: 0.9826 - val_loss: 0.0553
# Epoch 10/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9970 - loss: 0.0117 - val_accuracy: 0.9800 - val_loss: 0.0658
# Epoch 11/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9986 - loss: 0.0073 - val_accuracy: 0.9803 - val_loss: 0.0685
# Epoch 12/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9957 - loss: 0.0126 - val_accuracy: 0.9815 - val_loss: 0.0646
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 282,464 (1.08 MB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 188,310 (735.59 KB)
# None

# %%
test_loss, test_acc = model.evaluate(train_images, train_labels, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 532/532 - 1s - 2ms/step - accuracy: 0.9955 - loss: 0.0174
# Test accuracy: 0.9955

# %%
# Save model as .h5 file
model.save("devanagari_model.h5")
print("Model saved as devanagari_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as devanagari_model.h5

# %%
from tensorflow.keras.models import load_model

# Load the .h5 model
model = load_model("devanagari_model.h5")
print("Model loaded from devanagari_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded from devanagari_model.h5

# %%
# Use the model to make predictions on the test set
predictions = model.predict(train_images)

# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)

# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(train_labels[0])}")
# Out:
# 532/532 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predicted label for first image: 6
# True label for first image: 6

# %%
import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']

train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
